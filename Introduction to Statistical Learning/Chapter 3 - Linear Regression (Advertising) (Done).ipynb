# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Problem-formulation" data-toc-modified-id="Problem-formulation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Problem formulation</a></span></li><li><span><a href="#Read-data" data-toc-modified-id="Read-data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Read data</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#What-are-the-variable-types?" data-toc-modified-id="What-are-the-variable-types?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>What are the variable types?</a></span></li><li><span><a href="#Multivariate-analysis" data-toc-modified-id="Multivariate-analysis-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Multivariate analysis</a></span></li><li><span><a href="#Correlation-matrix" data-toc-modified-id="Correlation-matrix-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Correlation matrix</a></span><ul class="toc-item"><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Interpretation</a></span></li></ul></li></ul></li><li><span><a href="#Multiple-Linear-Regression" data-toc-modified-id="Multiple-Linear-Regression-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Multiple Linear Regression</a></span><ul class="toc-item"><li><span><a href="#Model-fit" data-toc-modified-id="Model-fit-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Model fit</a></span><ul class="toc-item"><li><span><a href="#Interpretation-of-regression-coefficients" data-toc-modified-id="Interpretation-of-regression-coefficients-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Interpretation of regression coefficients</a></span></li><li><span><a href="#Interpretation-of-t-stat" data-toc-modified-id="Interpretation-of-t-stat-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Interpretation of t-stat</a></span></li><li><span><a href="#Interpretation-of-p-values" data-toc-modified-id="Interpretation-of-p-values-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Interpretation of p-values</a></span></li><li><span><a href="#Interpretation-of-confidence-intervals" data-toc-modified-id="Interpretation-of-confidence-intervals-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Interpretation of confidence intervals</a></span></li></ul></li></ul></li><li><span><a href="#Q&amp;A:-Is-There-a-Relationship-Between-the-Response-and-Predictors?" data-toc-modified-id="Q&amp;A:-Is-There-a-Relationship-Between-the-Response-and-Predictors?-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Q&amp;A: Is There a Relationship Between the Response and Predictors?</a></span><ul class="toc-item"><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Interpretation</a></span><ul class="toc-item"><li><span><a href="#F-stat-and-associated-p-value" data-toc-modified-id="F-stat-and-associated-p-value-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>F-stat and associated p-value</a></span></li><li><span><a href="#Value-of-F-stat" data-toc-modified-id="Value-of-F-stat-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Value of F-stat</a></span></li><li><span><a href="#F-stat-vs.-T-stat" data-toc-modified-id="F-stat-vs.-T-stat-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>F-stat vs. T-stat</a></span></li></ul></li><li><span><a href="#Testing-that-Newspaper-is-a-non-significant-variable" data-toc-modified-id="Testing-that-Newspaper-is-a-non-significant-variable-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Testing that Newspaper is a non-significant variable</a></span><ul class="toc-item"><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Interpretation</a></span></li></ul></li><li><span><a href="#Is-the-remaining-relationship-linear?" data-toc-modified-id="Is-the-remaining-relationship-linear?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Is the remaining relationship linear?</a></span><ul class="toc-item"><li><span><a href="#Sales-vs.-TV" data-toc-modified-id="Sales-vs.-TV-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Sales vs. TV</a></span></li><li><span><a href="#Sales-vs.-Radio" data-toc-modified-id="Sales-vs.-Radio-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Sales vs. Radio</a></span></li><li><span><a href="#Interpretation-of-residual-plots" data-toc-modified-id="Interpretation-of-residual-plots-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Interpretation of residual plots</a></span></li></ul></li><li><span><a href="#Modelling" data-toc-modified-id="Modelling-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Modelling</a></span><ul class="toc-item"><li><span><a href="#Interpretation-of-confidence-intervals" data-toc-modified-id="Interpretation-of-confidence-intervals-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>Interpretation of confidence intervals</a></span></li><li><span><a href="#Visualizing-actual-data-against-model-prediction" data-toc-modified-id="Visualizing-actual-data-against-model-prediction-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>Visualizing actual data against model prediction</a></span></li><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>Interpretation</a></span></li></ul></li><li><span><a href="#Modelling-interaction-term" data-toc-modified-id="Modelling-interaction-term-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Modelling interaction term</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Interpretation-of-TV:Radio-coefficient" data-toc-modified-id="Interpretation-of-TV:Radio-coefficient-5.5.0.1"><span class="toc-item-num">5.5.0.1&nbsp;&nbsp;</span>Interpretation of TV:Radio coefficient</a></span></li><li><span><a href="#Interpretation-of-p-value-for-t-stat" data-toc-modified-id="Interpretation-of-p-value-for-t-stat-5.5.0.2"><span class="toc-item-num">5.5.0.2&nbsp;&nbsp;</span>Interpretation of p-value for t-stat</a></span></li><li><span><a href="#Comparison-of-R2" data-toc-modified-id="Comparison-of-R2-5.5.0.3"><span class="toc-item-num">5.5.0.3&nbsp;&nbsp;</span>Comparison of R2</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Prediction-modelling" data-toc-modified-id="Prediction-modelling-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Prediction modelling</a></span></li><li><span><a href="#Assessing-collinearity" data-toc-modified-id="Assessing-collinearity-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Assessing collinearity</a></span><ul class="toc-item"><li><span><a href="#Interpretation" data-toc-modified-id="Interpretation-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Interpretation</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Problem formulation
#
# **What is the business problem?**
# - How to increase sales via budget allocation for advertisements?
#     - What are the advertisment categories?
#         - TV/Radio/Newspaper
#
# **How do we decompose the business problem into data science problems? Have we changed the problem?**
# - How to predict sales via budget allocation for advertisements?
#     - Predict the sales given the level of advertisement in TV/Radio/Newspaper
#     - Linear regression of sales against TV/Radio/Newspaper
#
# - What proportion of variance in sales is affected by advertising budget? We don't want to focus on something insignificant. Perhaps a change in price could bring about bigger sales due to elasticity of demand.
#
# **Supervised or unsupervised?**
# - Supervised
#
# **Classification or regression?**
# - Regression
#
# **How important is interpretability vs. predictability?**
# - Is there a relationship between advertising sales and budget? (Inference)
# - Which media contribute to sales, and how strong is the relationship? (Inference)
# - Is the relationship linear? (Inference)
# - Is there synergy among the advertising media? (Inference)
# - How accurately can we predict future sales? (Prediction)
#
# **Is the target variable defined precisely? What are the values that it can take? Are there alternative ways to define the target variable that we have not considered?**
# - Sales, continuous variable
#
# **Are the attributes defined precisely? What are the values that it can take?**
# - TV - continuous variable
# - Newspaper - continuous variable
# - Radio - continuous variable
#
# **How will training data/test data be obtained? Is the company willing to invest in data collection?**
# - Historical data records
#
#     - Note that certain models perform better with less data. With less data, more complex models are more prone to overfitting.
#
#     - The learning curve can help the level of investment in data needed. We can slowly invest in data, examining whether our data is improving the performance, and whether extrapolating the curve indicates that there are more improvements to come. If the analysis shows that the investment is not worthwhile, we can stop investing in data collection.
#
# ** Is the data drawn from an unbiased population? If not, are the selection biases noted clearly? Is there a plan for how to compensate for them?**
#
# **What steps have been taken to prevent data leakage?**
#
# ** Does behavior change in direct response to the deployment of the model?**
# - Are we directly implementing the results of the model and storing the results together? Are we seperating a control group to test the effectiveness?
#
# ** What are the various models that may be tested on the problem?**
# - Continuous predictor = linear, lasso, ridge, GAM
#
# ** What metric will be used to judge the effectiveness of the model? Why is that specific metric being used and what alternatives should we consider?**
# - R2
# - RSS

# %% [markdown]
# # Read data

# %%
advertising = pd.read_csv('Data/Advertising.csv')
advertising.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
advertising.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# # EDA

# %%
profile = advertising.profile_report(title='Pandas Profiling Report')
profile.to_file(output_file="advertising.html")

# %% [markdown]
# ## What are the variable types?
#     - All continuous variables

# %% [markdown]
# ## Multivariate analysis

# %%
sns.set_style('darkgrid')
g = sns.PairGrid(advertising)
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
g = sns.jointplot("TV", "sales", data=advertising, kind="reg")

# %%
g = sns.jointplot("radio", "sales", data=advertising, kind="reg")

# %%
g = sns.jointplot("newspaper", "sales", data=advertising, kind="reg")

# %% [markdown]
# ## Correlation matrix

# %%
corr = advertising.corr()
sns.set_style('darkgrid')
sns.heatmap(corr,
            annot=True, # Displays the correlation value 
            linewidths=.5,
            xticklabels=True,
            yticklabels=True,
            cmap="RdBu_r", # Use a a diverging palette
            vmin=-1,
            vmax=1)

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Notice that the correlation between radio and newspaper is 0.35. This reveals a tendency to spend more on newspaper advertising in markets where more is spent on radio advertising.
#
# This suggests that any relationship between newspaper and sales holding radio advertising constant will be lower than the 0.23 correlation seen.

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.preprocessing import scale
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm # Note the short form
import statsmodels.formula.api as smf # Note the short form

# %%
advertising.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ## Model fit

# %%
estimates_overall = smf.ols('sales ~ TV + radio + newspaper', advertising).fit()
estimates_overall.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Interpretation of regression coefficients

# %% [markdown]
# For a given amount of TV and newspaper advertising, spending an additional $1,000 on radio advertising leads to an increase in sales by approximately 189 units
#
# For a given amount of radio and newspaper advertising, spending an additional $1,000 on TV advertising leads to an increase in sales by approximately 46 units
#
# There seems to be no relationship between sales and newspaper advertisments

# %% [markdown]
# ### Interpretation of t-stat

# %% [markdown]
# T-stat provide information about whether each individual predictor is related to the response, after adjusting for the other predictors

# %% [markdown]
# ### Interpretation of p-values

# %% [markdown]
# The corresponding p-value for newspaper is not significant, with a value around 0.86

# %% [markdown]
# ### Interpretation of confidence intervals

# %% [markdown]
# The confidence intervals for TV and radio are narrow and far from zero, providing evidence that these media are related to sales. But the interval for newspaper includes zero, indicating that the variable is not statistically significant given the values of TV and radio

# %% [markdown]
# # Q&A: Is There a Relationship Between the Response and Predictors?
#
# We answer this question by doing a hypothesis test on whether B1 = B2 = B3 = 0:
# - H0 : βTV = βradio = βnewspaper = 0 using the F-statistic.
# - If F-stat > 1/p-value >0.05 there is a relationship
# - If F-stat = 1/p-value <0.05 there is no relationship

# %%
estimates = smf.ols('sales ~ TV + radio + newspaper', advertising).fit()
estimates.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ## Interpretation

# %% [markdown]
# ### F-stat and associated p-value

# %% [markdown]
# F-stat>> 1:
# - it provides compelling evidence against the null hypothesis H0. In other words, the large F-statistic suggests that at least one of the advertising media must
# be related to sales.
#
# p-value associated with F-stat ~ 0:
# - extremely strong evidence that at least one of the media is associated with increased sales.

# %% [markdown]
# ### Value of F-stat

# %% [markdown]
# How large does the F-statistic need to be before we can reject H0 and
# conclude that there is a relationship?
#
# - It turns out that the answer depends
# on the values of n and p. When n is large, an F-statistic that is just a
# little larger than 1 might still provide evidence against H0. In contrast,
# a larger F-statistic is needed to reject H0 if n is small.

# %% [markdown]
# ### F-stat vs. T-stat

# %% [markdown]
# Given these individual p-values for each variable, why do we need to look at the overall F-statistic?
#
# "Torture the data long enough, and it will tell you what you want to hear"
#
# It seems likely that if any one of the p-values for the individual variables is very small, then at least one of the predictors is related to the response. However, this logic is flawed, especially when the number of predictors p is large.
#
# For instance, consider an example in which p = 100 and H0 : β1 = β2 = . . . = βp = 0 is true, so no variable is truly associated with the response. In this situation, about 5% of the p-values associated with each variable will be below 0.05 by chance. In other words, we expect to see approximately five small p-values even in the absence of any true association between the predictors and the response. we are almost guaranteed that we will observe at least one p-value below 0.05 by chance!
#
# Hence, if we use the individual t-statistics and associated p-values in order to decide whether or not there is any association between the variables and the response, there is a very high chance that we will incorrectly conclude that there is a relationship. However, the F-statistic does not suffer from this problem because it adjusts for the number of predictors.
#
# The approach of using an F-statistic to test for any association between the predictors and the response works when p is relatively small, and certainly small compared to n

# %% [markdown]
# ## Testing that Newspaper is a non-significant variable

# %% [markdown]
# - R2 is a measure of how much of the variance in Y is accounted for by the model.
#
# - Understand that R2 will always increase with the addition of new variables, because adding another variable to the least squares equations must allow us to fit the training data (though not necessarily the testing data) more accurately.
#
# - Size of R2 increase with predictor addition/removal is important, not just general increase

# %%
estimates_with_newspaper = smf.ols('sales ~ TV + radio + newspaper', advertising).fit()
estimates_with_newspaper.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
estimates_with_newspaper = smf.ols('sales ~ TV + radio', advertising).fit()
estimates_with_newspaper.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Interpretation

# %% [markdown]
# - Given the observation that R2 = 0.897 for both with and without Newspaper, we can verify that Newspaper is indeed a non-significant predictor

# %% [markdown]
# ## Is the remaining relationship linear?

# %% [markdown]
# ### Sales vs. TV

# %%
# Getting it to the same form as the one in the textbook
# with_std = False gets it to scale back to non-normalized variance
# Reshape(-1,1) -1 simply means that it is an unknown dimension and we want numpy to figure it out
# we just specify that we want 1 column
X = scale(advertising['TV'], with_mean=True, with_std=False).reshape(-1,1)
y = advertising['sales']
# Note that we are working with column vectors of (n,1) for X
# Note that we are working with (n,) for y
model = LinearRegression()
model.fit(X, y) 

advertising['Y_pred(TV)'] = model.predict(X) # Get Y_predict values

# Residual = Y_hat - Y
advertising['residual(TV)'] = advertising['sales'] - advertising['Y_pred(TV)']
         
# Residual Plot
sns.regplot(np.log(advertising['Y_pred(TV)']),
            advertising['residual(TV)'],
            lowess=True,
            line_kws={
                'color': 'r',
                'lw': 1
            }, scatter_kws={'facecolors':'k', 'alpha':0.4})
ax = plt.gca()
plt.hlines(0,xmin=ax.xaxis.get_data_interval()[0],
           xmax=ax.xaxis.get_data_interval()[1], linestyles='--')
plt.title('Residual Plot for Linear Fit')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### Sales vs. Radio

# %%
# Getting it to the same form as the one in the textbook
# with_std = False gets it to scale back to non-normalized variance
# Reshape(-1,1) -1 simply means that it is an unknown dimension and we want numpy to figure it out
# we just specify that we want 1 column
X = scale(advertising['radio'], with_mean=True, with_std=False).reshape(-1,1)
y = advertising['sales']
# Note that we are working with column vectors of (n,1) for X
# Note that we are working with (n,) for y

model.fit(X, y) 

advertising['Y_pred(Radio)'] = model.predict(X) # Get Y_predict values

# Residual = Y_hat - Y
advertising['residual(Radio)'] = advertising['sales'] - advertising['Y_pred(Radio)']
         
# Residual Plot
sns.regplot(advertising['Y_pred(Radio)'],
            advertising['residual(Radio)'],
            lowess=True,
            line_kws={
                'color': 'r',
                'lw': 1
            }, scatter_kws={'facecolors':'k', 'alpha':0.4})
ax = plt.gca()
plt.hlines(0,xmin=ax.xaxis.get_data_interval()[0],
           xmax=ax.xaxis.get_data_interval()[1], linestyles='--')
plt.title('Residual Plot for Linear Fit')
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
# Out:
# Text(0, 0.5, 'Residuals')

# %% [markdown]
# ### Interpretation of residual plots
# Residual plots show increasing deviation for higher values of Y, suggesting that there is departure from linearity.
#
# Regression plot shows that the positive residuals (those visible above the surface), tend to lie along the 45-degree line, where TV and Radio budgets are split evenly. The negative residuals (most not visible), tend to lie away from this line, where budgets are more lopsided. This strongly suggest that there are synergistic effects that are not accounted for in the linear model, where Radio might boost the effectiveness of TV and vice versa

# %% [markdown]
# ## Modelling

# %%
estimates_overall = smf.ols('sales ~ radio + TV', advertising).fit()
estimates_overall.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ### Interpretation of confidence intervals
# - Quantify uncertainty surrounding average sales
# - 95% of intervals of this form will contain the true value of f(X)

# %%
X = advertising[['radio', 'TV']]
y = advertising['sales']

# %%
model = skl_lm.LinearRegression()
model.fit(X,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [0.18799423 0.04575482]
# 2.9210999124051398

# %%
y_pred = model.predict(X)

# %% [markdown]
# ### Visualizing actual data against model prediction
#
# In addition to looking at the RSE and R2 statistics just discussed, it
# can be useful to plot the data. Graphical summaries can reveal problems
# with a model that are not visible from numerical statistics.

# %%
comparison = advertising
comparison['sales_pred'] = y_pred

# %%
# #  Having trouble with the surface plot for plotly
# trace1 = go.Scatter3d(x=comparison['TV'],
#                       y=comparison['radio'],
#                       z=comparison['sales'],
#                       mode='markers',
#                       name='Dummy Data',
#                       marker=dict(
#                                   opacity=0.9))
     
# # trace2 = go.Surface(
# #             x=comparison['TV'],
# #             y=comparison['radio'],
# #             z=comparison['sales_pred'],
# #             name='Plane of Best Fit',
# #             opacity = 0.7,
# #             colorscale='Greys',
# #             showscale= False
# #         )

# # data = [trace1, trace2]
# data = [trace1]

# layout = go.Layout(
#         title='3D Plane of Best Fit'
#     )

# fig = go.Figure(data=data, layout=layout)
# fig.show()

# %%
from mpl_toolkits.mplot3d import axes3d

# Create a coordinate grid
Radio = np.arange(0,50)
TV = np.arange(0,300)

B1, B2 = np.meshgrid(Radio, TV, indexing='xy')
Z = np.zeros((TV.size, Radio.size))

for (i,j),v in np.ndenumerate(Z):
        Z[i,j] =(model.intercept_ + B1[i,j]*model.coef_[0] + B2[i,j]*model.coef_[1])

# Create plot
fig = plt.figure(figsize=(10,6))
fig.suptitle('Regression: Sales ~ Radio + TV Advertising', fontsize=20)

ax = axes3d.Axes3D(fig)

ax.plot_surface(B1, B2, Z, rstride=10, cstride=5, alpha=0.4)
ax.scatter3D(advertising['radio'], advertising['TV'], advertising['sales'], c='r')

ax.set_xlabel('Radio')
ax.set_xlim(0,50)
ax.set_ylabel('TV')
ax.set_ylim(ymin=0)
ax.set_zlabel('Sales');
ax.view_init(30, 40)
# Out:
# D:\Anaconda\Anaconda\lib\site-packages\ipykernel_launcher.py:25: MatplotlibDeprecationWarning:
#
#
# The `ymin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `bottom` instead.

# %% [markdown]
# ### Interpretation
# The linear model seems to
# overestimate sales for instances in which most of the advertising money
# was spent exclusively on either TV or radio. It underestimates sales for
# instances where the budget was split between the two media.
#
# This pronounced
# non-linear pattern cannot be modeled accurately using linear regression

# %% [markdown]
# ## Modelling interaction term

# %%
est = smf.ols('sales ~ TV + radio + TV*radio', advertising).fit()
est.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
est.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# #### Interpretation of TV:Radio coefficient
# An increase in TV advertising of 1,000 is associated with increased sales of (β1+ β3 ×radio)×1,000 = 19+1.1×radio units.
#
# An increase in radio advertising of $1,000 will be associated with an increase in sales of ( ˆ β2 + ˆ β3 × TV) × 1,000 = 29 + 1.1 × TV units.

# %% [markdown]
# #### Interpretation of p-value for t-stat
#
# The p-value for the interaction term, TV×radio, is extremely low, indicating
# that there is strong evidence for Ha : β3 != 0.
#
# The hierarchical principle states that if we include an interaction in a model, we hierarchical should also include the main effects, even if the p-values associated with principle their coefficients are not significant

# %% [markdown]
# #### Comparison of R2

# %% [markdown]
# The R2 for the model is 96.8%, compared to only 89.7% for the model that predicts sales using TV and radio without an interaction term.
#
# This means that (96.8 − 89.7)/(100 − 89.7) = 69% of the variability in sales that remains after fitting the additive model has been explained by the interaction term

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline

# %%
poly = PolynomialFeatures(interaction_only=True,include_bias = False)
X_transform = poly.fit_transform(X)

# %%
X_transform.shape
# Out:
# (200, 3)

# %%
model = skl_lm.LinearRegression()
model.fit(X_transform,y)
print(model.coef_)
print(model.intercept_)
# Out:
# [0.02886034 0.01910107 0.00108649]
# 6.750220203075118

# %% [markdown]
# # Prediction modelling

# %%
X = advertising[['radio', 'TV']]
y = advertising['sales']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, train_size=0.7)

# %%
poly = PolynomialFeatures(interaction_only=True,include_bias = False)
model = make_pipeline(poly, LinearRegression())
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
model.get_params
# Out:
# <bound method Pipeline.get_params of Pipeline(memory=None,
#          steps=[('polynomialfeatures',
#                  PolynomialFeatures(degree=2, include_bias=False,
#                                     interaction_only=True, order='C')),
#                 ('linearregression',
#                  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                   normalize=False))],
#          verbose=False)>

# %%
mse = mean_squared_error(y_pred, y_test)
r2 = r2_score(y_pred, y_test)

print('MSE: ' + str(mse)) # sk_learn variable name holding B0
print('r2: ' + str(r2)) # sk_learn variable name holding B1, B2, B3
# Out:
# MSE: 1.4044453036848983
# r2: 0.9441125461585863

# %%
coeff = model.named_steps['linearregression'].coef_
intercept = model.named_steps['linearregression'].intercept_

# %%
print('intercept: ' + str(coeff)) # sk_learn variable name holding B0
print('gradient: ' + str(intercept)) # sk_learn variable name holding B1, B2, B3
# Out:
# intercept: [0.03580658 0.01881013 0.00106503]
# gradient: 6.742345401141966

# %% [markdown]
# # Assessing collinearity
#
# What is collinearity?
#
# Collinearity refers to the situation in which two or more predictor variables are closely related to one another.
# Why is collinearity important?
#
# The presence of collinearity can pose problems in the regression context, since it can be difficult to separate out the individual effects of collinear variables on the response.
#
# Since collinearity reduces the accuracy of the estimates of the regression coefficients, it causes the standard error for ˆβj to grow. Recall that the t-statistic for each predictor is calculated by dividing ˆβj by its standard error. Consequently, collinearity results in a decline in the t statistic. As a result, in the presence of collinearity, we may fail to reject H0 : βj = 0. This means that the power of the hypothesis test—the probability of correctly power detecting a non-zero coefficient—is reduced by collinearity.
#
# How to assess collinearity?
#
# DO NOT assess collinearity using correlation matrix plot.
# It is possible for collinearity to exist between three or more variables even if no pair of variables has a particularly high correlation. We call this situation multicollinearity
# DO assess collinearity using Variance Inflation Factor (VIF)
# VIF𝑗=11−𝑅2𝑗|𝑋−𝑗(1)
# {1-R_{j|X-j}^2} is the R2 from a regression of Xj onto all of the other predictors.
#
# VIF = 1 --> No collinearity
#
# VIF > 5 --> High collinearity
#
# What to do with collinear predictors?
#
# Drop one of the problematic variables from the regression
# Combine the standardized version of the collinear variables together into a single predictor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF_matrix = advertising[['TV','radio']]
# The function's author expects the presence of a constant in the matrix of explanatory variables.
VIF_matrix['const'] = 1 
VIF_matrix.head()
# Out:
# D:\Anaconda\Anaconda\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       TV  radio  const
# 0  230.1   37.8      1
# 1   44.5   39.3      1
# 2   17.2   45.9      1
# 3  151.5   41.3      1
# 4  180.8   10.8      1

# %%
VIF = pd.Series([variance_inflation_factor(VIF_matrix.values, i) 
               for i in range(VIF_matrix.shape[1])], 
              index=VIF_matrix.columns)
VIF
# Out:
# TV       1.003013
# radio    1.003013
# const    6.135476
# dtype: float64

# %% [markdown]
# ## Interpretation
# The VIF scores are 1.00,1.00 each, suggesting no evidence of collinearity.

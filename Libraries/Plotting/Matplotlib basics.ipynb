# %%
import pandas as pd
import numpy as np
from numpy.random import randn
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib notebook 
# interactive version
# %matplotlib inline
import seaborn as sns
import random
sns.set()

# %% [markdown]
# # Full plot template

# %% [markdown]
# ## Plt

# %%
dy = 0.2
dx = 1

random.seed(0)
x = np.arange(0, 100)
y1 = np.random.randn(100)
y2 = np.random.randn(100) + dy

fig0, ax0 = plt.subplots()
plt.title('A random distribution')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.plot(x, y1, color='k', linestyle='--', label='dist1', alpha=0.1)
plt.plot(x, y2, color='k', linestyle='-', marker='o', label='dist2')
# plt.plot? for full range of options
plt.errorbar(x,
             y2,
             yerr=dy,
             xerr=dx,
             fmt='o',
             color='k',
             ecolor='darkgray',
             elinewidth=1,
             capsize=2)
# ecolor sets the color of errorbar, make it lighter than the plot for clarity
# elinewidth sets thickness of errorbar
# capsize sets the presence of a cap line at the end of the error bar
# For full list of colors:
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html
plt.legend(loc='best', frameon=False, ncol=2)

# Method 1 for limits
# plt.xlim(0, 50)
# plt.ylim(-3, 3)

# Method 2 for limits
plt.axis('tight')
# plt.axis([-1, 11, -1.5, 1.5])
# Check plt.axis? for full range of phrases

# Method 1 for ticks
# ax.xaxis.set_major_locator(plt.MultipleLocator(20))
# ax.yaxis.set_major_locator(plt.MultipleLocator(1))

# Method 2 for ticks
ax.xaxis.set_major_locator(plt.MaxNLocator(11))
ax.yaxis.set_major_locator(plt.MaxNLocator(11))

# Annotating POI
ax.text(93, 2.5, ". Max point", transform=ax.transData)

# Save fig
# plt.savefig('Desktop\Results\Test.png',
#             bbox_inches='tight',
#             transparent=False,
#             dpi=200)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(93, 2.5, '. Max point')

# %% [markdown]
# ## OOP

# %%
dy = 0.2
dx = 1

random.seed(0)
x = np.arange(0, 100)
y1 = np.random.randn(100)
y2 = np.random.randn(100) + dy

fig2, ax1 = plt.subplots()
ax1.set_title('A random distribution')
ax1.set_xlabel('x')
ax1.set_ylabel('f(x)')
ax1.plot(x, y1, color='k', linestyle='--', label='dist1', alpha=0.1)
ax1.plot(x, y2, color='k', linestyle='-', marker='o', label='dist2')

# plt.errorbar(x,
#              y2,
#              yerr=dy,
#              xerr=dx,
#              fmt='o',
#              color='k',
#              ecolor='darkgray',
#              elinewidth=1,
#              capsize=2)
# ecolor sets the color of errorbar, make it lighter than the plot for clarity
# elinewidth sets thickness of errorbar
# capsize sets the presence of a cap line at the end of the error bar
# For full list of colors:
# https://matplotlib.org/3.1.0/gallery/color/named_colors.html
ax1.legend(loc='best', frameon=False, ncol=2)

# Method 1 for limits
# plt.xlim(0, 50)
# plt.ylim(-3, 3)

# Method 2 for limits
ax1.axis('tight')
# plt.axis([-1, 11, -1.5, 1.5])
# Check plt.axis? for full range of phrases

# Method 1 for ticks
# ax.xaxis.set_major_locator(plt.MultipleLocator(20))
# ax.yaxis.set_major_locator(plt.MultipleLocator(1))

# Method 2 for ticks
ax1.xaxis.set_major_locator(plt.MaxNLocator(11))
ax1.yaxis.set_major_locator(plt.MaxNLocator(11))

# Annotating POI
ax1.text(93, 2.5, ". Max point", transform=ax.transData)

# # Save fig
plt.savefig('Desktop\Results\Test2.png',
            bbox_inches='tight',
            transparent=False,
            dpi=200)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Subplot template

# %% [markdown]
# ## OOP subplots

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax1.plot(randn(50).cumsum(), 'k--')
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
ax3.hist(randn(100), bins=20, color='k', alpha=0.3)
# Out:
# (array([ 1.,  0.,  3.,  4.,  1.,  4.,  7.,  6.,  8.,  8.,  8., 11.,  6.,
#          4., 12.,  5.,  3.,  4.,  3.,  2.]),
#  array([-2.4521267 , -2.21188153, -1.97163635, -1.73139118, -1.49114601,
#         -1.25090084, -1.01065567, -0.7704105 , -0.53016532, -0.28992015,
#         -0.04967498,  0.19057019,  0.43081536,  0.67106054,  0.91130571,
#          1.15155088,  1.39179605,  1.63204122,  1.87228639,  2.11253157,
#          2.35277674]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ## Plt subplots

# %%
fig, axes = plt.subplots(2, 2)
plt.subplots_adjust(wspace=None, hspace=None)

axes[0,0].plot(randn(50).cumsum(), 'k--')
axes[0,1].scatter(np.arange(30), np.arange(30) + 3 * randn(30))
axes[1,0].hist(randn(100), bins=20, color='k', alpha=0.3)
# Out:
# (array([ 1.,  1.,  2.,  1.,  5.,  8.,  8.,  9., 10.,  7.,  4., 10.,  4.,
#          9.,  6.,  3.,  8.,  1.,  1.,  2.]),
#  array([-2.31207859, -2.09255552, -1.87303245, -1.65350938, -1.43398631,
#         -1.21446324, -0.99494017, -0.7754171 , -0.55589403, -0.33637096,
#         -0.11684789,  0.10267518,  0.32219825,  0.54172132,  0.76124439,
#          0.98076746,  1.20029054,  1.41981361,  1.63933668,  1.85885975,
#          2.07838282]),
#  <a list of 20 Patch objects>)
